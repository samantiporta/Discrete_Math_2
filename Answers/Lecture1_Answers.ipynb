# %% [markdown]
# # Name: Marc Dylan Myles C. Pilapil
# # Course: BSCS-1
# # Id: 23102730
# # Questions:
# ---
#
# ### Why is Proof Necessary?
#
# Proofs play a vital role in confirming whether a statement or theorem is true. They provide logical reasoning that demonstrates the validity of a claim, ensuring its reliability under specific circumstances. This reliability enables us to use the statement confidently in various calculations, deductions, or practical applications.
#
#
# ### Consequences of Failing to Provide a Proof
#
# Without a proof, we can't be sure if a statement or theorem is true. This uncertainty makes it hard to know if the claim applies in different situations. So, the statement stays uncertain, making it tough to use in solving problems or understanding things better.

# %% [markdown]
# Problem no. 1 Prove that the Euler's number $e = \Sigma_{k=0}^\infty \frac{1}{k!} \notin \mathbb{Q}$.
# ---
# Recall that a rational number is one that can be expressed as the quotient of two integers. We want to prove that Euler's number $e = \sum_{k=0}^\infty \frac{1}{k!} \notin \mathbb{Q}$.
#
# **Proof by Contradiction**
#
# We will assume the opposite (that `e` is rational) and show that this leads to a contradiction.
#
# * **Definition of Rational Numbers:**
#
# A rational number is any number that can be expressed as a quotient (`a / b`), where `a` and `b` are integers, and `b ≠ 0`.
#
# * **Assume e is Rational:**
#
# For the sake of contradiction, let's assume `e` can be expressed as a fraction `a / b`, where `a` and `b` are integers.
#
# * **Series Expansion of e:**
#
# We know the series expansion of `e`:
#
# $$ e = \sum_{k=0}^\infty \frac{1}{k!} = 1 + \frac{1}{1!} + \frac{1}{2!} + \frac{1}{3!} + \dotsb $$
#
# * **Multiplying by b!**
#
# Let's multiply both sides of the equation by `b!` to eliminate the factorials:
#
# $$ b!e = b! \left(1 + \frac{1}{1!} + \frac{1}{2!} + \frac{1}{3!} + \dotsb \right) = b! (1 + b + \frac{b(b-1)}{2!} + \frac{b(b-1)(b-2)}{3!} + \dotsb) $$
#
# * **Contradiction:**
#
# Observe that every term on the right side of the equation is now a multiple of `b!` because it includes `b!` or a product of factors containing `b`. Since the product of integers is an integer, the entire right side becomes an integer. This contradicts our initial assumption that `e = a / b` (where `b` is an integer).
#
# Therefore, our assumption that `e` is rational must be false.
#
# **Conclusion:**
#
# By contradiction, we have proven that Euler's number `e` is irrational (i.e., it cannot be expressed as a fraction of two integers).
#
# Observe that since each term on the right side of the equation is a multiple of $b!$, the entire expression is an integer. Consequently, if $e$ were rational, it would contradict our initial assumption. Thus, $e \notin \mathbb{Q}$.

# %% [markdown]
# Problem no. 2
# Prove Minkowski's Inequality for sums, $\forall \ p>1, (a_k, b_k)>0$:
# ---
#
# We want to prove Minkowski's Inequality for sums and thus:
# \[ $\left(\sum_{k=1}^n |a_k + b_k|^p\right)^\frac{1}{p} \leq \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} + \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} $\]
#
# $\textit{Proof:}$
#
# The proof involves utilizing Hölder's inequality. Let \( q \) be the conjugate exponent of \( p \). (i.e., $\frac{1}{p} + \frac{1}{q} = 1$).
#
# Apply Hölder's inequality with $p$ and $q$ to the sequences $(|a_k|^p)$ and $(1)$, and to the sequences $(|b_k|^p)$ and $(1)$:
#
# \[ $\sum_{k=1}^n |a_k|^p \cdot 1 \leq \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} \left(\sum_{k=1}^n 1^q\right)^\frac{1}{q} = \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} $\]
#
# then.
#
# \[ $\sum_{k=1}^n |b_k|^p \cdot 1 \leq \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} \left(\sum_{k=1}^n 1^q\right)^\frac{1}{q} = \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} $\]
#
# Add these inequalities:
#
# \[ $\sum_{k=1}^n |a_k|^p + \sum_{k=1}^n |b_k|^p \leq \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} + \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} $\]
#
# then.
#
# \[ $\sum_{k=1}^n (|a_k|^p + |b_k|^p) \leq \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} + \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} $\]
#
# After this we raise both sides to the power of $\frac{1}{p}$:
#
# \[ $\left(\sum_{k=1}^n (|a_k|^p + |b_k|^p)\right)^\frac{1}{p} \leq \left(\left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q} + \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} \cdot n^\frac{1}{q}\right)^\frac{1}{p} $\]
#
# then.
#
# \[ $\left(\sum_{k=1}^n (|a_k + b_k|^p)\right)^\frac{1}{p} \leq \left(\sum_{k=1}^n |a_k|^p\right)^\frac{1}{p} + \left(\sum_{k=1}^n |b_k|^p\right)^\frac{1}{p} $\]
#
# Thus this then proves Minkowski's Inequality.

# %% [markdown]
# Problem no. 3 Prove the triangle inequality $|x+y| \leq |x| + |y|, \forall (x,y) \in \mathbb{R}$
# ---
#
# $\textit{Proof:}$
#
# Consider these three cases:
#
# 1. If $x \geq 0$ and $y \geq 0$, then $|x| = x$ and $|y| = y$, so $|x+y| = x+y$. Then $|x+y| = x + y \leq |x| + |y|$.
#
# 3. If $x \geq 0$ and $y < 0$, then $|x| = x$ and $|y| = -y$, so $|x+y| = x-y$. Then $|x+y| = x - y \leq |x| + |y|$.
#
# 4. If $x < 0$ and $y < 0$, then $|x| =
# -x$ and $|y| = -y$, so $|x+y| = -(x+y) = -x - y$. Then $|x+y| = -(x + y) \leq |x| + |y|$.

# %% [markdown]
# ## Problem 4: Prove Sedrakayan's Lemma
#
# **Lemma:** $\forall u_i, v_i \in \mathbb{R}^+$:
#
# $\frac{(\sum_{i=1}^n u_i)^2}{\sum_{i=1}^n v_i} \leq \sum_{i=1}^n \frac{(u_i)^2}{v_i}$
#
# **Proof:**
#
# 1. **Define vectors:** Let $\mathbf{u} = (u_1, u_2, ..., u_n)$ and $\mathbf{v} = (v_1, v_2, ..., v_n)$ be vectors in $\mathbb{R}^+$.
#
# 2. **Cauchy-Schwarz Inequality:** Apply Cauchy-Schwarz Inequality:
#
# $(\sum_{i=1}^n u_i v_i)^2 \leq (\sum_{i=1}^n u_i^2) (\sum_{i=1}^n v_i^2)$
#
# 3. **Divide by norm:** Since $v_i > 0$ for all $i$, divide both sides by $\sum_{i=1}^n v_i^2$:
#
# $\frac{(\sum_{i=1}^n u_i v_i)^2}{(\sum_{i=1}^n v_i^2)} \leq \sum_{i=1}^n u_i^2$
#
# 4. **Vector notation:** Introduce vector dot product $(\mathbf{u} \cdot \mathbf{v})$ and Euclidean norm $\|\cdot\|$:
#
# $\frac{(\mathbf{u} \cdot \mathbf{v})^2}{\|\mathbf{v}\|^2} \leq \|\mathbf{u}\|^2$
#
# 5. **Square both sides:**
#
# $\frac{(\mathbf{u} \cdot \mathbf{v})^2}{\|\mathbf{v}\|^4} \leq \frac{\|\mathbf{u}\|^2}{\|\mathbf{v}\|^2}$
#
# 6. **Substitute and rearrange:** Substitute $\|\mathbf{v}\|^2 = \sum_{i=1}^n v_i$ and rearrange:
#
# ## $\frac{(\sum_{i=1}^n u_i)^2}{\sum_{i=1}^n v_i} \leq \sum_{i=1}^n \frac{u_i^2}{v_i}$

# %% [markdown]
# ## Problem 5
#
# Consider the functions $ f(x) = 2x + 1 , ( g(x) = 2y - 1 ), ( j(x) = |f(x) + g(x)| ), and ( h(x) = j(x)^2 )$. Show that the following inequality holds:
#
# $\sqrt{|f(x)|^2} \geq \sqrt{h(x)} - \sqrt{|g(x)|^2}, \quad \forall (x, y) \in \mathbb{Z}^+
# $
#
# Thus then we substitute the functions:
#
# $
# \sqrt{(2x+1)^{2}} \geq \sqrt{|(2x + 1) + (2y - 1)|^{2}} - \sqrt{(2y-1)^{2}}
# $
#
# Given the properties of absolute value, we understand that certain mathematical principles and inequalities are valid.
#
# $
# \sqrt{(x)^{2}} = |x|
# $
#
# Thus we get this:
#
# $
# |2x + 1| \geq |(2x + 1) + (2y - 1)| - |2y - 1|
# $

# %% [markdown]
# Let's simplify the expression by assigning variables to the terms:
#
# Let $a = 2x + 1$ and $b = 2y - 1$
#
# $
# |a| \geq |a + b| - |b|
# $
#
# By adding $|b|$ to both sides and subtracting $|a|$, we arrive at:
#
# $
# |a + b| \leq |a| + |b|
# $
#
#
# The provided inequality simply represents the triangle inequality theorem.

# %% [markdown]
# ## PROBLEM 6: Sedrakayan's Lemma  2
#
# Demonstrate Sedrakayan's Lemma when $u_i$ and $v_i$ are square roots of an even integer, where $u_i = 2a_i$ and $v_i = 2b_i$, with $a_i, b_i$ being integers.
#
# ## $\frac{(\sum_{i=1}^{n}2a_i)^{2}}{\sum_{i=1}^{n}2b_i} \leq \sum_{i=1}^{n} \frac{(2a_i)^{2}}{2b_i}$
#
# then simplified to:
#
# ## $ \frac{4(\sum_{i=1}^{n}a_i)^{2}}{2\sum_{i=1}^{n}b_i} \leq \sum_{i=1}^{n} \frac{4(a_i)^{2}}{2b_i}$
#
# then simplified to:
#
# ## $\frac{2(\sum_{i=1}^{n}a_i)^{2}}{\sum_{i=1}^{n}b_i} \leq 2\space[\sum_{i=1}^{n} \frac{(a_i)^{2}}{b_i}]$
#
# both sides need to be multiplied by $\frac{1}{2}$
#
# ## $\frac{(\sum_{i=1}^{n}a_i)^{2}}{\sum_{i = 1}^{n}b_i} \leq \sum_{i=i}^{n} \frac{(a_i)^{2}}{b_i}$
#
#
# In conclusion, Sedrakayan's Lemma states that for square roots of an even integer, represented by
# are integers. This holds true.
